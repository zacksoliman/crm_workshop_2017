# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.parse import quote_plus, urlencode, urlparse, urlunparse
import pandas as pd
import re
import json
import lxml.html

# %%
data_path = "CleanedDescription.csv"
df = pd.read_csv(data_path)

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'IBCSplitCode', 'IBCCodeDescription', 'CleanText'], dtype=object)

# %% [markdown]
# # Fetch Wikipedia pages

# %% [markdown]
# For every descriptor (leaf) we will fetch wikipedia entries returned by bing

# %%
code_url_map = {}

with open('codes_url_map.txt', 'w') as f:
    for code, description in zip(df.IBCSplitCode, df.CleanText.values):
        clean_description = re.sub(r"\b(noc|\n\.o\.c\.|incl|etc\.|_|\(|\)|e\.g\.|other|otherthanpoultry|coc)\b", "", description)
        clean_description = re.sub(r"\bmanufactur\.\b", "manufacturing", clean_description)
        clean_description = re.sub(r"otherthan.*$", "", clean_description)
        
        payload = {"q":description}
        result = urlencode(payload, quote_via=quote_plus)
        r = urlopen("http://www.bing.com/search?" + result).read()
        dom =  lxml.html.fromstring(r)
        url_list = dom.xpath('//a/@href')
        code_url_map[code] = url_list
        
        f.write(code + ":" + str(url_list) + "\n")

# %%
import pickle

pickle.(code_url_map, open('code_url_map.pkl', 'wb'))

# %% [markdown]
# # Clean url map

# %% [markdown]
# ## We get the wikipedia links

# %%
import pickle

code_url_map = pickle.load(open('code_url_map.pkl', 'rb'))

# %%
len(code_url_map)
# Out:
# 1203

# %%
for key in code_url_map.keys():
    code_url_map[key] = [urlparse(url).netloc + urlparse(url).path for url in code_url_map[key] if "wikipedia" in url]

# %%
code_url_map = {k: list(set(v)) for k, v in code_url_map.items() if v}

# %%
code_url_map
# Out:
# {'0121a00': ['en.wikipedia.org/wiki/Nut_(fruit)'],
#  '0121b00': ['simple.wikipedia.org/wiki/List_of_fruits',
#   'en.wikipedia.org/wiki/Fruitarianism'],
#  '0121d00': ['en.wikipedia.org/wiki/Potato_farm'],
#  '0122a00': ['en.wikipedia.org/wiki/Cover_crop'],
#  '0123a00': ['en.wikipedia.org/wiki/Greenhouse'],
#  '0130a00': ['en.wikipedia.org/wiki/Dairy',
#   'en.wikipedia.org/wiki/Dairy_farming'],
#  '0140a00': ['en.wikipedia.org/wiki/Horse_breeding'],
#  '0150a20': ['en.wikipedia.org/wiki/Egg_(food)',
#   'en.wikipedia.org/wiki/Poultry_farming'],
#  '0150z00': ['en.wikipedia.org/wiki/Poultry_farming',
#   'en.wikipedia.org/wiki/Poultry'],
#  '0160a00': ['en.wikipedia.org/wiki/Beefalo'],
#  '0170a00': ['en.wikipedia.org/wiki/Hog_Farm',
#   'en.wikipedia.org/wiki/Pig_farming'],
#  '0190a00': ['en.wikipedia.org/wiki/Goat-sheep_chimerae',
#   'en.wikipedia.org/wiki/Special:Random',
#   'en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Sheep%E2%80%93goat_hybrid',
#   'en.wikipedia.org/wiki/Sheep–goat_hybrid',
#   'en.wikipedia.org/wiki/Sheep_(zodiac)',
#   'en.wikipedia.org/wiki/Category:Bovid_hybrids'],
#  '0190b00': ['en.wikipedia.org/wiki/Alpaca',
#   'en.wikipedia.org/wiki/Lama_glama'],
#  '0190c00': ['en.wikipedia.org/wiki/Roosevelt_elk',
#   'en.wikipedia.org/wiki/Irish_mythology',
#   'en.wikipedia.org/wiki/Irish_elk',
#   'en.wikipedia.org/wiki/Elk_Island_National_Park',
#   'en.wikipedia.org/wiki/Oscar_(Irish_mythology)',
#   'en.wikipedia.org/wiki/Elk',
#   'en.wikipedia.org/wiki/Eastern_elk',
#   'en.wikipedia.org/wiki/Impetigo',
#   'en.wikipedia.org/wiki/Cervidae',
#   'en.wikipedia.org/wiki/Wikipedia:Featured_articles'],
#  '0190d00': ['en.wikipedia.org/wiki/Help:Contents',
#   'en.wikipedia.org/wiki/Portal:Contents',
#   'en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Special:Random',
#   'en.wikipedia.org/wiki/Apiary',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '0190f30': ['en.wikipedia.org/wiki/The_Farm_%28The_Office%29'],
#  '0190z00': ['en.wikipedia.org/wiki/Animal_Farm'],
#  '0190z10': ['en.wikipedia.org/wiki/Animal_Farm'],
#  '0200a00': ['en.wikipedia.org/wiki/Cultivation_of_tobacco',
#   'en.wikipedia.org/wiki/Ontario_tobacco_belt'],
#  '0210a00': ['en.wikipedia.org/wiki/Fur_farming'],
#  '0630a00': ['en.wikipedia.org/wiki/Peat_moss', 'en.wikipedia.org/wiki/Peat'],
#  '0730a00': ['en.wikipedia.org/wiki/Artificial_inseminator'],
#  '0730b00': ['en.wikipedia.org/wiki/Grass_cutting'],
#  '0730z00': ['en.wikipedia.org/wiki/Horticulture'],
#  '0731a20': ['en.wikipedia.org/wiki/Custom_harvesting'],
#  '0735a00': ['en.wikipedia.org/wiki/Landscaping'],
#  '0742a00': ['en.wikipedia.org/wiki/Feedlot'],
#  '0791a00': ['en.wikipedia.org/wiki/Lumbering'],
#  '0981a00': ['en.wikipedia.org/wiki/Fish_hatchery'],
#  '0982a00': ['en.wikipedia.org/wiki/Commercial_fishing'],
#  '1001a00': ['en.wikipedia.org/wiki/Metal_mining',
#   'en.wikipedia.org/wiki/Mining'],
#  '1002a00': ['en.wikipedia.org/wiki/Mining',
#   'en.wikipedia.org/wiki/Prospecting'],
#  '1101a00': ['en.wikipedia.org/wiki/Underground_coal_mining',
#   'en.wikipedia.org/wiki/Underground_mining'],
#  '1102a00': ['en.wikipedia.org/wiki/Surface_coal_mine',
#   'en.wikipedia.org/wiki/Surface_mining'],
#  '1391a00': ['en.wikipedia.org/wiki/Levelized_energy_cost'],
#  '1393a10': ['en.wikipedia.org/wiki/Oil_and_gas_drilling'],
#  '1393c00': ['en.wikipedia.org/wiki/Coiled_tubing'],
#  '1394a00': ['en.wikipedia.org/wiki/Oil_well_control',
#   'en.wikipedia.org/wiki/Well_control'],
#  '1394a30': ['en.wikipedia.org/wiki/Workover'],
#  '1394a40': ['en.wikipedia.org/wiki/Perforation_(oil_well)',
#   'en.wikipedia.org/wiki/Perforation'],
#  '1394a50': ['en.wikipedia.org/wiki/Rate_of_penetration',
#   'en.wikipedia.org/wiki/Well_logging',
#   'en.wikipedia.org/wiki/Category:Well_logging',
#   'en.wikipedia.org/wiki/World_Petroleum_Council'],
#  '1394a60': ['en.wikipedia.org/wiki/Slickline',
#   'en.wikipedia.org/wiki/Wireline_%28cabling%29'],
#  '1394c00': ['en.wikipedia.org/wiki/Oil_rigs'],
#  '1394g00': ['en.wikipedia.org/wiki/Pipe_insulation'],
#  '1394h00': ['en.wikipedia.org/wiki/Land_reclamation_in_Monaco',
#   'en.wikipedia.org/wiki/Land_reclamation_in_Hong_Kong',
#   'en.wikipedia.org/wiki/Category:Land_reclamation',
#   'en.wikipedia.org/wiki/Land_reclamation',
#   'en.wikipedia.org/wiki/Praya_Reclamation_Scheme'],
#  '1394h10': ['en.wikipedia.org/wiki/Environmental_remediation'],
#  '1395b30': ['en.wikipedia.org/wiki/Operated_equipment_rental'],
#  '1395c10': ['en.wikipedia.org/wiki/Mud_tank'],
#  '1396a00': ['en.wikipedia.org/wiki/Operation_Pluto',
#   'en.wikipedia.org/wiki/Pipeline_transport'],
#  '1396b00': ['en.wikipedia.org/wiki/Pigging',
#   'en.wikipedia.org/wiki/Pig_farming'],
#  '1397b10': ['en.wikipedia.org/wiki/Exploration_geophysics',
#   'en.wikipedia.org/wiki/Seismic_exploration'],
#  '1403a00': ['en.wikipedia.org/wiki/Quarry'],
#  '1511a00': ['en.wikipedia.org/wiki/Raising_of_Chicago',
#   'en.wikipedia.org/wiki/House_raising'],
#  '1513a00': ['en.wikipedia.org/wiki/Underpinning'],
#  '1523a00': ['en.wikipedia.org/wiki/Sidewalk'],
#  '1524a00': ['en.wikipedia.org/wiki/Drainage_system_%28agriculture%29'],
#  '1525b00': ['en.wikipedia.org/wiki/Snow_removal'],
#  '1526a00': ['en.wikipedia.org/wiki/Land_grading'],
#  '1528a00': ['en.wikipedia.org/wiki/Street_cleaning'],
#  '1534a00': ['en.wikipedia.org/wiki/Antenna_(radio)'],
#  '1622a00': ['en.wikipedia.org/wiki/Cofferdam'],
#  '1623a00': ['en.wikipedia.org/wiki/Breakwater_(structure)'],
#  '1624a00': ['en.wikipedia.org/wiki/Dredging'],
#  '1625a00': ['en.wikipedia.org/wiki/Hydro-electric_dam',
#   'en.wikipedia.org/wiki/List_of_reservoirs_and_dams_in_Canada'],
#  '1631x00': ['en.wikipedia.org/wiki/Ice_road',
#   'en.wikipedia.org/wiki/Snow_removal'],
#  '1633a00': ['en.wikipedia.org/wiki/Construction_of_the_Trans-Alaska_Pipeline_System',
#   'en.wikipedia.org/wiki/Pipeline_transport'],
#  '1634a00': ['en.wikipedia.org/wiki/Railroad_construction'],
#  '1635a00': ['en.wikipedia.org/wiki/Tunnel',
#   'en.wikipedia.org/wiki/New_York_City_Subway',
#   'en.wikipedia.org/wiki/Cincinnati_Subway'],
#  '1636a00': ['en.wikipedia.org/wiki/Pipeline_transport'],
#  '1638a00': ['en.wikipedia.org/wiki/Shaft_construction'],
#  '1713b00': ['en.wikipedia.org/wiki/Pipe_fitting',
#   'en.wikipedia.org/wiki/Pipe_fittings'],
#  '1715b00': ['en.wikipedia.org/wiki/Geothermal_heating'],
#  '1716a00': ['en.wikipedia.org/wiki/Central_heating_and_cooling'],
#  '1731x00': ['en.wikipedia.org/wiki/Wireline_%28cabling%29'],
#  '1732a00': ['en.wikipedia.org/wiki/Overhead_line'],
#  '1741x00': ['en.wikipedia.org/wiki/Casing_(borehole)'],
#  '1745a00': ['en.wikipedia.org/wiki/Terrazzo'],
#  '1752a00': ['en.wikipedia.org/wiki/Carpenter_shop'],
#  '1754a00': ['en.wikipedia.org/wiki/International_Union_of_Painters_and_Allied_Trades',
#   'en.wikipedia.org/wiki/House_painter_and_decorator'],
#  '1757a00': ['en.wikipedia.org/wiki/Interior_design'],
#  '1764a00': ['en.wikipedia.org/wiki/Ironworker'],
#  '1770a00': ['en.wikipedia.org/wiki/Water_well',
#   'en.wikipedia.org/wiki/Drilling_fluid'],
#  '1770b00': ['en.wikipedia.org/wiki/Drill', 'en.wikipedia.org/wiki/Drilling'],
#  '1771a00': ['en.wikipedia.org/wiki/Stevedore'],
#  '1772a00': ['en.wikipedia.org/wiki/Shipbuilding'],
#  '1776a00': ['en.wikipedia.org/wiki/List_of_commercially_available_roofing_material'],
#  '1780a00': ['en.wikipedia.org/wiki/Portal:Contents',
#   'en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Wikipedia:Citation_needed',
#   'en.wikipedia.org/wiki/Liquefied_petroleum_gas',
#   'en.wikipedia.org/wiki/Fireproofing',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '1782f00': ['en.wikipedia.org/wiki/Sewage_treatment'],
#  '1783a10': ['en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/FROGS_(rebreather)',
#   'en.wikipedia.org/wiki/Hydrostatic_test',
#   'en.wikipedia.org/wiki/Wikipedia:Please_clarify',
#   'en.wikipedia.org/wiki/Wikipedia:Citation_needed',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '1783a20': ['en.wikipedia.org/wiki/Nondestructive_testing'],
#  '1783b00': ['en.wikipedia.org/wiki/Nondestructive_testing'],
#  '1783x20': ['en.wikipedia.org/wiki/Nondestructive_testing'],
#  '1812a00': ['en.wikipedia.org/wiki/Renovation'],
#  '1830d00': ['en.wikipedia.org/wiki/Architectural_preservation',
#   'en.wikipedia.org/wiki/Architectural_preservationist'],
#  '2001a00': ['en.wikipedia.org/wiki/Meatpacking_District,_Manhattan',
#   'en.wikipedia.org/wiki/Meat_packing_industry'],
#  '2001b00': ['en.wikipedia.org/wiki/Meatpacking_District,_Manhattan',
#   'en.wikipedia.org/wiki/Meat_packing_industry'],
#  '2001c00': ['en.wikipedia.org/wiki/Poultry_processing'],
#  '2001d00': ['en.wikipedia.org/wiki/Smokehouse',
#   'en.wikipedia.org/wiki/Smoked_meat'],
#  '2002a00': ['en.wikipedia.org/wiki/Union_Stockyards_(Omaha)',
#   'en.wikipedia.org/wiki/Union_Stock_Yards'],
#  '2002b00': ['en.wikipedia.org/wiki/Union_Stockyards_(Omaha)',
#   'en.wikipedia.org/wiki/Union_Stock_Yards'],
#  '2003a00': ['en.wikipedia.org/wiki/Seafood_processing'],
#  '2003b00': ['en.wikipedia.org/wiki/Smoked_fish'],
#  '2003c00': ['en.wikipedia.org/wiki/Smoked_fish'],
#  '2011a00': ['en.wikipedia.org/wiki/Manufacture_of_Cheddar_cheese',
#   'en.wikipedia.org/wiki/Cheesemaking'],
#  '2011c00': ['en.wikipedia.org/wiki/Creamery'],
#  '2030a00': ['en.wikipedia.org/wiki/Baby_food'],
#  '2041b00': ['en.wikipedia.org/wiki/Animal_feed',
#   'en.wikipedia.org/wiki/Fodder'],
#  '2042a00': ['en.wikipedia.org/wiki/Cereal',
#   'en.wikipedia.org/wiki/Whole_grain',
#   'en.wikipedia.org/wiki/Food_grain'],
#  '2043a00': ['en.wikipedia.org/wiki/Cereal',
#   'en.wikipedia.org/wiki/Whole_grain',
#   'en.wikipedia.org/wiki/Food_grain'],
#  '2044b00': ['en.wikipedia.org/wiki/Feed_mill'],
#  '2051a00': ['en.wikipedia.org/wiki/Bakery'],
#  '2051b00': ['en.wikipedia.org/wiki/National_Pasta_Association'],
#  '2052a00': ['en.wikipedia.org/wiki/Category:Snack_companies_of_the_United_States'],
#  '2052c00': ['en.wikipedia.org/wiki/List_of_bean-to-bar_chocolate_manufacturers'],
#  '2052z00': ['/search', 'en.wikipedia.org/wiki/Confectionery'],
#  '2060a00': ['en.wikipedia.org/wiki/Molasses'],
#  '2081a00': ['en.wikipedia.org/wiki/Malt_house'],
#  '2081b00': ['en.wikipedia.org/wiki/Vinegar'],
#  '2081c00': ['en.wikipedia.org/wiki/Winery'],
#  '2082a00': ['en.wikipedia.org/wiki/Organoleptic',
#   'en.wikipedia.org/wiki/Bottled_water_in_the_United_States',
#   'en.wikipedia.org/wiki/List_of_bottled_water_brands',
#   'en.wikipedia.org/wiki/Wikipedia:Article_wizard',
#   'en.wikipedia.org/wiki/Food_Act_1981',
#   'en.wikipedia.org/wiki/Bottled_water'],
#  '2082b00': ['en.wikipedia.org/wiki/List_of_soft_drinks_by_country',
#   'en.wikipedia.org/wiki/Soft_drink'],
#  '2090a00': ['en.wikipedia.org/wiki/BD80'],
#  '2291a00': ['en.wikipedia.org/wiki/Textile_manufacturing'],
#  '2310b00': ['en.wikipedia.org/wiki/Tailor'],
#  '2331a00': ['en.wikipedia.org/wiki/Fur_clothing'],
#  '2352d00': ['en.wikipedia.org/wiki/Ribbon'],
#  '2420a00': ['en.wikipedia.org/wiki/Plywood'],
#  '2420b00': ['en.wikipedia.org/wiki/Planing_mill'],
#  '2491a00': ['en.wikipedia.org/wiki/Wood_drying'],
#  '2494a00': ['en.wikipedia.org/wiki/Boat_building'],
#  '2620a00': ['en.wikipedia.org/wiki/Pulp_(paper)'],
#  '2632b00': ['en.wikipedia.org/wiki/Wallpaper'],
#  '2633a00': ['en.wikipedia.org/wiki/Envelope'],
#  '2710b00': ['en.wikipedia.org/wiki/Publishing'],
#  '2750a00': ['en.wikipedia.org/wiki/Publishing'],
#  '2750b00': ['en.wikipedia.org/wiki/Bookbinding'],
#  '2750d00': ['en.wikipedia.org/wiki/Lithography',
#   'en.wikipedia.org/wiki/X-ray_lithography',
#   'en.wikipedia.org/wiki/Scanning_probe_lithography',
#   'en.wikipedia.org/wiki/Stencil_lithography',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '2811a00': ['en.wikipedia.org/wiki/Zinc-carbon_battery',
#   'en.wikipedia.org/wiki/Dry_cell',
#   'en.wikipedia.org/wiki/Battery_%28electricity%29'],
#  '2811b00': ['en.wikipedia.org/wiki/Lead%E2%80%93acid_battery',
#   'en.wikipedia.org/wiki/Wet_cell'],
#  '2812b00': ['en.wikipedia.org/wiki/Industrial_gas'],
#  '2813a00': ['en.wikipedia.org/wiki/Industrial_gas'],
#  '2815a00': ['en.wikipedia.org/wiki/Lacquer'],
#  '2815b00': ['en.wikipedia.org/wiki/Varnish'],
#  '2820z00': ['en.wikipedia.org/wiki/Special:Search'],
#  '2833a00': ['en.wikipedia.org/wiki/Patent_medicine',
#   'en.wikipedia.org/wiki/Generic_drug',
#   'en.wikipedia.org/wiki/Pharmaceutical_drug'],
#  '2850a00': ['en.wikipedia.org/wiki/Munitions',
#   'en.wikipedia.org/wiki/Category:Explosives_manufacturers'],
#  '2850b00': ['en.wikipedia.org/wiki/Fertilizer'],
#  '2850c00': ['en.wikipedia.org/wiki/Hindustan_Shipyard_Limited',
#   'en.wikipedia.org/wiki/List_of_modern_armament_manufacturers',
#   'en.wikipedia.org/wiki/Constructions_industrielles_de_la_M%C3%A9diterran%C3%A9e',
#   'en.wikipedia.org/wiki/Talk:List_of_modern_armament_manufacturers',
#   'en.wikipedia.org/wiki/Ind%C3%BAstria_Naval_do_Cear%C3%A1',
#   'en.wikipedia.org/wiki/Hellenic_Aerospace_Industry'],
#  '2872a00': ['en.wikipedia.org/wiki/Adhesive'],
#  '2873a00': ['en.wikipedia.org/wiki/List_of_commonly_available_chemicals',
#   'en.wikipedia.org/wiki/Sulphur_Bank_Mine'],
#  '2981b00': ['en.wikipedia.org/wiki/List_of_oil_refineries',
#   'en.wikipedia.org/wiki/Oil_refinery',
#   'en.wikipedia.org/wiki/Petroleum_refining_processes'],
#  '2990a00': ['en.wikipedia.org/wiki/Waxes'],
#  '3062a00': ['en.wikipedia.org/wiki/Tire_recycling'],
#  '3064a00': ['en.wikipedia.org/wiki/Condom'],
#  '3065a00': ['en.wikipedia.org/wiki/Combustibility'],
#  '3066a00': ['en.wikipedia.org/wiki/Combustibility'],
#  '3072a00': ['en.wikipedia.org/wiki/Compact_Disc_manufacturing'],
#  '3072b00': ['en.wikipedia.org/wiki/X-ray_photography',
#   'en.wikipedia.org/wiki/Photographic_film',
#   'en.wikipedia.org/wiki/List_of_photographic_equipment_makers'],
#  '3073a00': ['en.wikipedia.org/wiki/Celluloid'],
#  '3073b00': ['en.wikipedia.org/wiki/Plastics_extrusion'],
#  '3073c00': ['en.wikipedia.org/wiki/Staedtler'],
#  '3282a00': ['en.wikipedia.org/wiki/Glassblowing',
#   'en.wikipedia.org/wiki/Glass_production'],
#  '3282b00': ['en.wikipedia.org/wiki/Glass',
#   'en.wikipedia.org/wiki/Glass_production'],
#  '3282c00': ['en.wikipedia.org/wiki/Mirror'],
#  '3291b00': ['en.wikipedia.org/wiki/Cement_plaster'],
#  '3292a00': ['en.wikipedia.org/wiki/Ready-mix_concrete'],
#  '3294a00': ['en.wikipedia.org/wiki/Precast_concrete'],
#  '3296a00': ['en.wikipedia.org/wiki/Soapstone'],
#  '3297a00': ['en.wikipedia.org/wiki/Abrasive'],
#  '3320a00': ['en.wikipedia.org/wiki/Foundry'],
#  '3320b00': ['en.wikipedia.org/wiki/Steel_mill',
#   'en.wikipedia.org/wiki/List_of_steel_producers'],
#  '3360b00': ['en.wikipedia.org/wiki/Aluminium_smelting',
#   'en.wikipedia.org/wiki/List_of_aluminium_smelters'],
#  '3360d00': ['en.wikipedia.org/wiki/Flash_smelting',
#   'en.wikipedia.org/wiki/Aluminium_smelting',
#   'en.wikipedia.org/wiki/Special:Random',
#   'en.wikipedia.org/wiki/Matte_(metallurgy)',
#   'en.wikipedia.org/wiki/Smelting',
#   'en.wikipedia.org/wiki/Wikipedia:Citation_needed',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '3491a00': ['en.wikipedia.org/wiki/Category:Audio_equipment_manufacturers'],
#  '3492a00': ['en.wikipedia.org/wiki/Commodore_International',
#   'en.wikipedia.org/wiki/Calculator'],
#  '3493a00': ['en.wikipedia.org/wiki/Tape_storage',
#   'en.wikipedia.org/wiki/Tape_drive',
#   'en.wikipedia.org/wiki/Mainframe_computer'],
#  '3495a00': ['en.wikipedia.org/wiki/Semiconductor_device_fabrication',
#   'en.wikipedia.org/wiki/Electronics_and_semiconductor_manufacturing_industry_in_India'],
#  '3496a00': ['en.wikipedia.org/wiki/Electronic_game',
#   'en.wikipedia.org/wiki/Electronic_Games'],
#  '3570b00': ['en.wikipedia.org/wiki/Hand_tool',
#   'en.wikipedia.org/wiki/Power_tool'],
#  '3590b00': ['en.wikipedia.org/wiki/Wire_rope'],
#  '3590d00': ['en.wikipedia.org/wiki/Cutlery'],
#  '3590e00': ['en.wikipedia.org/wiki/Gear_manufacturing'],
#  '3590f00': ['en.wikipedia.org/wiki/Machining',
#   'en.wikipedia.org/wiki/Machine_shop'],
#  '3590i00': ['en.wikipedia.org/wiki/Tinware'],
#  '3590j00': ['en.wikipedia.org/wiki/Tool_and_die_maker'],
#  '3590x00': ['en.wikipedia.org/wiki/Metal_fabrication'],
#  '3591a00': ['en.wikipedia.org/wiki/Boat-building'],
#  '3592a00': ['en.wikipedia.org/wiki/Metal_furniture'],
#  '3597a00': ['en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Special:Random',
#   'en.wikipedia.org/wiki/Electroplating',
#   'en.wikipedia.org/wiki/Nickel_electroplating',
#   'en.wikipedia.org/wiki/Wikipedia:Please_clarify',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '3691a00': ['en.wikipedia.org/wiki/ASME_Boiler_and_Pressure_Vessel_Code',
#   'en.wikipedia.org/wiki/Pressure_vessel'],
#  '3694a00': ['en.wikipedia.org/wiki/Agricultural_machinery_industry'],
#  '3790z00': ['en.wikipedia.org/wiki/Transport_engineering'],
#  '3797a00': ['en.wikipedia.org/wiki/List_of_aircraft_manufacturers_A',
#   'en.wikipedia.org/wiki/Aerospace_manufacturer'],
#  '3798a00': ['en.wikipedia.org/wiki/Saint_John_Shipbuilding',
#   'en.wikipedia.org/wiki/Newport_News_Shipbuilding_%26_Dry_Dock_Company',
#   'en.wikipedia.org/wiki/Sun_Shipbuilding_%26_Drydock_Co.',
#   'en.wikipedia.org/wiki/Dry_dock'],
#  '3799a00': ['en.wikipedia.org/wiki/Rolling_stock',
#   'en.wikipedia.org/wiki/Great_Central_Railway_locomotives',
#   'en.wikipedia.org/wiki/List_of_Vale_of_Rheidol_Railway_rolling_stock'],
#  '3821a00': ['en.wikipedia.org/wiki/List_of_photographic_equipment_makers'],
#  '3826z00': ['en.wikipedia.org/wiki/Scientific_instrument'],
#  '3871a00': ['en.wikipedia.org/wiki/List_of_clock_manufacturers',
#   'en.wikipedia.org/wiki/List_of_United_States_clock_companies'],
#  '3970a00': ['en.wikipedia.org/wiki/Excelsior_Motor_Manufacturing_%26_Supply_Company'],
#  '3982a00': ['en.wikipedia.org/wiki/Hindustan_Shipyard_Limited',
#   'en.wikipedia.org/wiki/List_of_modern_armament_manufacturers',
#   'en.wikipedia.org/wiki/Constructions_industrielles_de_la_M%C3%A9diterran%C3%A9e',
#   'en.wikipedia.org/wiki/Arms_industry',
#   'en.wikipedia.org/wiki/Talk:List_of_modern_armament_manufacturers',
#   'en.wikipedia.org/wiki/Ind%C3%BAstria_Naval_do_Cear%C3%A1',
#   'en.wikipedia.org/wiki/Hellenic_Aerospace_Industry'],
#  '3983a00': ['en.wikipedia.org/wiki/Sporting_goods'],
#  '4000a00': ['en.wikipedia.org/wiki/Rail_transport_operations'],
#  '4111a00': ['en.wikipedia.org/wiki/Armored_car_(valuables)',
#   'en.wikipedia.org/wiki/Loomis_(company)'],
#  '4112a00': ['en.wikipedia.org/wiki/Toronto_Transit_Commission'],
#  '4113a00': ['en.wikipedia.org/wiki/Toronto_Coach_Terminal',
#   'en.wikipedia.org/wiki/Bus_terminus'],
#  '4115a00': ['en.wikipedia.org/wiki/Rescue_squad',
#   'en.wikipedia.org/wiki/Ambulance_Service'],
#  '4117a00': ['en.wikipedia.org/wiki/Towing'],
#  '4117b00': ['en.wikipedia.org/wiki/Truck_driver'],
#  '4117d60': ['en.wikipedia.org/wiki/Natural-gas_condensate'],
#  '4118a00': ['en.wikipedia.org/wiki/Courier'],
#  '4118b00': ['en.wikipedia.org/wiki/Courier'],
#  '4120c00': ['simple.wikipedia.org/wiki/Airport_terminal',
#   'en.wikipedia.org/wiki/Airport_terminal',
#   'en.wikipedia.org/wiki/Toronto_Pearson_International_Airport'],
#  '4210a00': ['en.wikipedia.org/wiki/Grain_terminal',
#   'en.wikipedia.org/wiki/List_of_grain_elevators'],
#  '4220a00': ['en.wikipedia.org/wiki/List_of_grain_elevators',
#   'en.wikipedia.org/wiki/Grain_elevator'],
#  '4231a00': ['en.wikipedia.org/wiki/Stanley_Dock_Tobacco_Warehouse'],
#  '4251b00': ['en.wikipedia.org/wiki/Sperm_bank'],
#  '4263a00': ['en.wikipedia.org/wiki/Moving_company'],
#  '4281a00': ['en.wikipedia.org/wiki/Cooper_River_Distillers'],
#  '4462a00': ['en.wikipedia.org/wiki/Wharf'],
#  '4479a00': ['en.wikipedia.org/wiki/Panama_Canal',
#   'en.wikipedia.org/wiki/Panama_Canal_locks'],
#  '4580a00': ['en.wikipedia.org/wiki/Hangar'],
#  '4811a00': ['en.wikipedia.org/wiki/Communications_service_provider'],
#  '4812a00': ['en.wikipedia.org/wiki/Cablevision'],
#  '4820a00': ['en.wikipedia.org/wiki/Telegraphy',
#   'en.wikipedia.org/wiki/Electrical_telegraph'],
#  '4871a00': ['en.wikipedia.org/wiki/Freight_forwarder'],
#  '4891a00': ['en.wikipedia.org/wiki/Public_broadcasting',
#   'en.wikipedia.org/wiki/Television_station',
#   'en.wikipedia.org/wiki/List_of_television_stations_in_Mexico',
#   'en.wikipedia.org/wiki/List_of_CBC_television_stations'],
#  '4892a00': ['en.wikipedia.org/wiki/BBC_Television_Centre'],
#  '4910a00': ['en.wikipedia.org/wiki/List_of_pre-nationalisation_UK_electric_power_companies',
#   'en.wikipedia.org/wiki/Category:Power_companies_of_the_United_States',
#   'en.wikipedia.org/wiki/List_of_United_States_electric_companies'],
#  '4950a00': ['en.wikipedia.org/wiki/List_of_wind_farms_in_Canada',
#   'en.wikipedia.org/wiki/Wind_farm',
#   '/search'],
#  '4950b00': ['en.wikipedia.org/wiki/Photovoltaic_system',
#   'en.wikipedia.org/wiki/Photovoltaics',
#   'en.wikipedia.org/wiki/Solar_power'],
#  '4950z00': ['en.wikipedia.org/wiki/Combined_heat_power'],
#  '4951a00': ['en.wikipedia.org/wiki/Garbage_dump'],
#  '4952a00': ['en.wikipedia.org/wiki/Waste_management',
#   'en.wikipedia.org/wiki/Municipal_solid_waste'],
#  '4955a00': ['en.wikipedia.org/wiki/Sewage_treatment',
#   'en.wikipedia.org/wiki/Sanitary_sewer'],
#  '4956a00': ['en.wikipedia.org/wiki/Hazardous_waste'],
#  '4957a00': ['en.wikipedia.org/wiki/Irrigation'],
#  '4959a00': ['en.wikipedia.org/wiki/Pigging'],
#  '5032a00': ['en.wikipedia.org/wiki/Cosmetics'],
#  '5041a00': ['en.wikipedia.org/wiki/Fertilizer',
#   'en.wikipedia.org/wiki/Ammonium_nitrate'],
#  '5042a00': ['en.wikipedia.org/wiki/Liquefied_petroleum_gas'],
#  '5044a00': ['en.wikipedia.org/wiki/Radionuclide',
#   'en.wikipedia.org/wiki/Radioactive'],
#  '5045a00': ['en.wikipedia.org/wiki/Environmental_impact_of_pesticides',
#   'en.wikipedia.org/wiki/Pesticide'],
#  '5053a00': ['en.wikipedia.org/wiki/Fur_clothing'],
#  '5055a00': ['en.wikipedia.org/wiki/Women_wearing_trousers_in_the_Western_world_after_1900'],
#  '5060a00': ['en.wikipedia.org/wiki/Anijsmelk',
#   'en.wikipedia.org/wiki/File:Milkproducts_v2.svg',
#   'en.wikipedia.org/wiki/List_of_dairy_products',
#   'en.wikipedia.org/wiki/Dairy_product',
#   'en.wikipedia.org/wiki/Cuisine_of_Guinea-Bissau',
#   'en.wikipedia.org/wiki/Ossetian_cuisine',
#   'en.wikipedia.org/wiki/Gambian_cuisine'],
#  '5061a00': ['en.wikipedia.org/wiki/Non-alcoholic_beverage'],
#  '5063a00': ['en.wikipedia.org/wiki/Produce',
#   'en.wikipedia.org/wiki/Portal:Contents',
#   'en.wikipedia.org/wiki/Produce_traceability',
#   'en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Special:Random',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '5064a00': ['en.wikipedia.org/wiki/Animal_feed'],
#  '5080a00': ['en.wikipedia.org/wiki/Tobacco_product'],
#  '5091a00': ['en.wikipedia.org/wiki/Small_appliance',
#   'en.wikipedia.org/wiki/Home_appliance'],
#  '5093a00': ['en.wikipedia.org/wiki/Hvac'],
#  '5101a00': ['en.wikipedia.org/wiki/Outline_of_industrial_machinery',
#   'en.wikipedia.org/wiki/Machine_industry'],
#  '5108a00': ['en.wikipedia.org/wiki/Ground_support_equipment'],
#  '5112a00': ['en.wikipedia.org/wiki/Autogas',
#   'en.wikipedia.org/wiki/Liquefied_petroleum_gas'],
#  '5114a00': ['en.wikipedia.org/wiki/Oil_terminal',
#   'en.wikipedia.org/wiki/Tank_farm'],
#  '5122a00': ['en.wikipedia.org/wiki/Waste_paper'],
#  '5140a00': ['en.wikipedia.org/wiki/Category:Paper_products'],
#  '5154a00': ['en.wikipedia.org/wiki/Carpet'],
#  '5161a00': ['en.wikipedia.org/wiki/Lumber_yard'],
#  '5172a00': ['en.wikipedia.org/wiki/Clocks_and_Watches'],
#  '5172b00': ['en.wikipedia.org/wiki/Gemstone',
#   'en.wikipedia.org/wiki/List_of_precious_stones_in_the_Bible'],
#  '5180a00': ['en.wikipedia.org/wiki/Periodical_literature'],
#  '5191a00': ['en.wikipedia.org/wiki/Thermoplastic'],
#  '5196b00': ['en.wikipedia.org/wiki/Sporting_goods'],
#  '5212a00': ['en.wikipedia.org/wiki/Category:Marble',
#   'en.m.wikipedia.org/wiki/Marble',
#   'en.m.wikipedia.org/wiki/Special:Random',
#   'en.wikipedia.org/wiki/Creole_marble',
#   'en.wikipedia.org/wiki/Ruin_marble',
#   'en.wikipedia.org/wiki/Tiles'],
#  '5221b00': ['en.wikipedia.org/wiki/Precious_metal'],
#  '5231a00': ['en.wikipedia.org/wiki/IBM',
#   'en.wikipedia.org/wiki/UNISERVO',
#   'en.wikipedia.org/wiki/IBM_726',
#   'en.wikipedia.org/wiki/Tape_drive',
#   'en.wikipedia.org/wiki/Tape_storage',
#   'en.wikipedia.org/wiki/Remington_Rand',
#   'en.wikipedia.org/wiki/IBM_729',
#   'en.wikipedia.org/wiki/Mainframe_computer'],
#  '5240a00': ['en.wikipedia.org/wiki/Methane_clathrate',
#   'en.wikipedia.org/wiki/Solids'],
#  '5252a00': ['en.wikipedia.org/wiki/Improvised_firearm'],
#  '5259a00': ['en.wikipedia.org/wiki/Dishware'],
#  '5291a00': ['en.wikipedia.org/wiki/Builder%27s_risk_insurance'],
#  '5301a00': ['en.wikipedia.org/wiki/Enclosed_mall',
#   'en.wikipedia.org/wiki/List_of_shopping_malls_in_Metro_Manila'],
#  '5302a00': ['en.wikipedia.org/wiki/Open_air_market',
#   'en.wikipedia.org/wiki/Market_%28place%29'],
#  '5314z00': ['en.wikipedia.org/wiki/List_of_largest_enclosed_shopping_malls_in_Canada'],
#  '5321a00': ['en.wikipedia.org/wiki/List_of_department_stores',
#   'en.wikipedia.org/wiki/Department_store'],
#  '5322a00': ['en.wikipedia.org/wiki/Kaufmann%27s',
#   'en.wikipedia.org/wiki/Department_stores'],
#  '5341a00': ['en.wikipedia.org/wiki/Door-to-door'],
#  '5342a00': ['en.wikipedia.org/wiki/Mail_order'],
#  '5421a00': ['en.wikipedia.org/wiki/Deep_frying'],
#  '5422a00': ['en.wikipedia.org/wiki/Anijsmelk',
#   'en.wikipedia.org/wiki/File:Milkproducts_v2.svg',
#   'en.wikipedia.org/wiki/List_of_dairy_products',
#   'en.wikipedia.org/wiki/Dairy_product',
#   'en.wikipedia.org/wiki/Cuisine_of_Guinea-Bissau',
#   'en.wikipedia.org/wiki/Ossetian_cuisine',
#   'en.wikipedia.org/wiki/Gambian_cuisine'],
#  '5433a00': ['en.wikipedia.org/wiki/Grocery_store',
#   'en.wikipedia.org/wiki/List_of_supermarket_chains_in_the_United_States'],
#  '5433d00': ['en.wikipedia.org/wiki/Delicatessen',
#   'en.wikipedia.org/wiki/Delicatessen_(film)'],
#  '5511a00': ['en.wikipedia.org/wiki/Used_car'],
#  '5522a00': ['en.wikipedia.org/wiki/Filling_station'],
#  '5524a00': ['en.wikipedia.org/wiki/Car_wash'],
#  '5524b00': ['en.wikipedia.org/wiki/Auto_detailing'],
#  '5532a00': ['en.wikipedia.org/wiki/Retread'],
#  '5711a00': ['en.wikipedia.org/wiki/Picture_frame'],
#  '5714a00': ['en.wikipedia.org/wiki/Electronic_waste',
#   'en.wikipedia.org/wiki/Consumer_electronics'],
#  '5715a00': ['en.wikipedia.org/wiki/Sound_recording_and_reproduction'],
#  '5811a20': ['en.wikipedia.org/wiki/Deep-fried_pizza',
#   'en.wikipedia.org/wiki/Deep-fry'],
#  '5811b00': ['en.wikipedia.org/wiki/Fast_food_restaurant',
#   'en.wikipedia.org/wiki/List_of_fast_food_restaurants'],
#  '5811c00': ['en.wikipedia.org/wiki/Family_restaurant',
#   'en.wikipedia.org/wiki/The_Family_Restaurant'],
#  '5812a20': ['en.wikipedia.org/wiki/Deep-fried_pizza'],
#  '5812b00': ['en.wikipedia.org/wiki/Fast_food_restaurant'],
#  '5813b00': ['en.wikipedia.org/wiki/Stewart%27s_Drive-In'],
#  '5813c00': ['en.wikipedia.org/wiki/Internet_caf%C3%A9'],
#  '5814a00': ['en.wikipedia.org/wiki/Take-out'],
#  '5823a00': ['en.wikipedia.org/wiki/Discotheque'],
#  '5823b00': ['en.wikipedia.org/wiki/Tavern',
#   'en.wikipedia.org/wiki/Bar_(establishment)'],
#  '5912a00': ['en.wikipedia.org/wiki/List_of_pharmacies'],
#  '5920a00': ['en.wikipedia.org/wiki/Bottle_shop'],
#  '5940a00': ['en.wikipedia.org/wiki/Pawnbroker'],
#  '5984a00': ['en.wikipedia.org/wiki/Liquefied_petroleum_gas'],
#  '5990a00': ['/search'],
#  '5991a00': ['en.wikipedia.org/wiki/Convenience_store'],
#  '5991b00': ['en.wikipedia.org/wiki/Tobacconist'],
#  '5993b00': ['en.wikipedia.org/wiki/Bookselling'],
#  '5995a00': ['simple.wikipedia.org/wiki/Indonesia',
#   'simple.wikipedia.org/wiki/India',
#   'en.wikipedia.org/wiki/General_Santos',
#   'simple.wikipedia.org/wiki/People%27s_Republic_of_China',
#   'simple.wikipedia.org/wiki/List_of_countries_by_population',
#   'en.wikipedia.org/wiki/Japan',
#   'simple.wikipedia.org/wiki/United_States'],
#  '5996b00': ['en.wikipedia.org/wiki/Flea_market'],
#  '5996c00': ['en.wikipedia.org/wiki/Handicraft'],
#  '5996h00': ['en.wikipedia.org/wiki/Toy'],
#  '5998a00': ['en.wikipedia.org/wiki/Variety_store',
#   'en.wikipedia.org/wiki/Discount_store'],
#  '6022a00': ['en.wikipedia.org/wiki/Trust_company'],
#  '6023a00': ['en.wikipedia.org/wiki/Foreign_bank',
#   'en.wikipedia.org/wiki/List_of_banks_in_India'],
#  '6120a00': ['en.wikipedia.org/wiki/Caisses_populaires',
#   'en.wikipedia.org/wiki/List_of_banks_and_credit_unions_in_Canada'],
#  '6140a00': ['en.wikipedia.org/wiki/Credit_bureau'],
#  '6150a00': ['en.wikipedia.org/wiki/Institutional_investor',
#   'en.wikipedia.org/wiki/Financial_institution'],
#  '6210a00': ['en.wikipedia.org/wiki/Broker-dealer'],
#  '6230a00': ['en.wikipedia.org/wiki/Commodities_trading',
#   'en.wikipedia.org/wiki/Commodity_broker'],
#  '6230b10': ['en.wikipedia.org/wiki/Commodity_broker'],
#  '6240a00': ['en.wikipedia.org/wiki/Stock_exchange',
#   'en.wikipedia.org/wiki/Commodities_exchange'],
#  '6250a00': ['en.wikipedia.org/wiki/Foreign_exchange_market'],
#  '6390a00': ['en.wikipedia.org/wiki/Pension'],
#  '6411a00': ['en.wikipedia.org/wiki/Audit'],
#  '6411b00': ['en.wikipedia.org/wiki/Bookkeeping'],
#  '6412a00': ['en.wikipedia.org/wiki/Insurance_broker'],
#  '6412b00': ['en.wikipedia.org/wiki/Claims_adjuster'],
#  '6414a00': ['en.wikipedia.org/wiki/List_of_management_consulting_firms',
#   'en.wikipedia.org/wiki/Management_consulting'],
#  '6501a00': ['en.wikipedia.org/wiki/Building_Owners_and_Managers_Association'],
#  '6520a00': ['en.wikipedia.org/wiki/Subdivision_(land)'],
#  '6531a00': ['en.wikipedia.org/wiki/Category:House_styles',
#   'en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Townhouse_(Great_Britain)',
#   'en.wikipedia.org/wiki/Townhouse',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '6532a00': ['en.wikipedia.org/wiki/Apartment'],
#  '6541a00': ['en.wikipedia.org/wiki/Wikipedia:Community_Portal',
#   'en.wikipedia.org/wiki/Hydrogen_peroxide',
#   'en.wikipedia.org/wiki/Portal:Contents',
#   'en.wikipedia.org/wiki/Building_occupancy_classifications',
#   'en.wikipedia.org/wiki/Special:Random'],
#  '6542a00': ['en.wikipedia.org/wiki/Wikipedia:Community_Portal',
#   'en.wikipedia.org/wiki/Hydrogen_peroxide',
#   'en.wikipedia.org/wiki/Portal:Contents',
#   'en.wikipedia.org/wiki/Building_occupancy_classifications',
#   'en.wikipedia.org/wiki/Special:Random'],
#  '6550a00': ['en.wikipedia.org/wiki/Tenement',
#   'en.wikipedia.org/wiki/Apartment'],
#  '6580a00': ['en.wikipedia.org/wiki/Real_estate_broker'],
#  '6632a00': ['en.wikipedia.org/wiki/Builder%27s_risk_insurance'],
#  '6650a00': ['en.wikipedia.org/wiki/Strata_title'],
#  '6650a10': ['en.wikipedia.org/wiki/Cooperative',
#   'en.wikipedia.org/wiki/British_co-operative_movement'],
#  '6660a10': ['en.wikipedia.org/wiki/Housing_cooperative',
#   'en.wikipedia.org/wiki/Building_occupancy_classifications'],
#  '6670a00': ['en.wikipedia.org/wiki/Condominium'],
#  '6670b00': ['en.wikipedia.org/wiki/Strata_title'],
#  '6670c00': ['en.wikipedia.org/wiki/California_Supreme_Court',
#   'en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Wikipedia:Article_wizard',
#   'en.wikipedia.org/wiki/Homeowner_association'],
#  '7031a00': ['en.wikipedia.org/wiki/Boarding_House'],
#  '7031b00': ['en.wikipedia.org/wiki/North_American_fraternity_and_sorority_housing'],
#  '7041a00': ['en.wikipedia.org/wiki/Summer_camp'],
#  '7041b00': ['en.wikipedia.org/wiki/Guest_ranch'],
#  '7051a00': ['en.wikipedia.org/wiki/Alamo_Plaza_Hotel_Courts'],
#  '7052a00': ['en.wikipedia.org/wiki/Alamo_Plaza_Hotel_Courts'],
#  '7054a00': ['en.wikipedia.org/wiki/Bed_and_breakfast'],
#  '7061a00': ['en.wikipedia.org/wiki/Motor_court'],
#  '7063a00': ['en.wikipedia.org/wiki/Motor_court'],
#  '7210a00': ['en.wikipedia.org/wiki/Self-service_laundry'],
#  '7220b00': ['/search'],
#  '7221a00': ['en.wikipedia.org/wiki/Dry_cleaning'],
#  '7262a00': ['en.wikipedia.org/wiki/Crematoria',
#   'en.wikipedia.org/wiki/Crematory'],
#  '7291a00': ['en.wikipedia.org/wiki/Funeral_director'],
#  '7292a00': ['en.wikipedia.org/wiki/Major_film_studio',
#   'en.wikipedia.org/wiki/Film_studio'],
#  '7292b00': ['en.wikipedia.org/wiki/Photographic_studio'],
#  '7294a00': ['en.wikipedia.org/wiki/Aerial_photography'],
#  '7297a00': ['en.wikipedia.org/wiki/Beauty_salon'],
#  '7298a00': ['en.wikipedia.org/wiki/Tour_operator'],
#  '7312a00': ['en.wikipedia.org/wiki/Advertising_agency',
#   'en.wikipedia.org/wiki/List_of_advertising_agencies'],
#  '7312b00': ['en.wikipedia.org/wiki/List_of_marketing_research_firms'],
#  '7312c00': ['en.wikipedia.org/wiki/Telemarketing'],
#  '7313b00': ['en.wikipedia.org/wiki/Public_relations'],
#  '7320a00': ['en.wikipedia.org/wiki/Collection_agency'],
#  '7391a00': ['en.wikipedia.org/wiki/Fumigation'],
#  '7393a00': ['en.wikipedia.org/wiki/Property_manager',
#   'en.wikipedia.org/wiki/Property_management'],
#  '7394a00': ['en.wikipedia.org/wiki/Janitor'],
#  '7401a00': ['en.wikipedia.org/wiki/Auction'],
#  '7403b00': ['en.wikipedia.org/wiki/Safety_patrol'],
#  '7403c00': ['en.wikipedia.org/wiki/Private_investigator'],
#  '7407a00': ['en.wikipedia.org/wiki/Datacenter'],
#  '7407b00': ['en.wikipedia.org/wiki/Computer-assisted_dispatch'],
#  '7408a10': ['en.wikipedia.org/wiki/Event_Planning'],
#  '7408a20': ['en.wikipedia.org/wiki/Professional_Conference_Organiser'],
#  '7408b10': ['en.wikipedia.org/wiki/Careers_Advisory_Services'],
#  '7408c10': ['en.wikipedia.org/wiki/Human_resource_consulting'],
#  '7408c20': ['en.wikipedia.org/wiki/Project_management'],
#  '7408c40': ['en.wikipedia.org/wiki/Wedding_planner'],
#  '7408d10': ['en.wikipedia.org/wiki/Blueprint'],
#  '7408e00': ['en.wikipedia.org/wiki/Author', 'en.wikipedia.org/wiki/Montreal'],
#  '7408f00': ['en.wikipedia.org/wiki/Genealogy'],
#  '7408g00': ['en.wikipedia.org/wiki/Herbalism'],
#  '7408h00': ['en.wikipedia.org/wiki/Patent_attorney'],
#  '7408i00': ['en.wikipedia.org/wiki/Recording_studio'],
#  '7408k00': ['en.wikipedia.org/wiki/Tax_assessment'],
#  '7408l00': ['en.wikipedia.org/wiki/Taxidermy_(disambiguation)',
#   'en.wikipedia.org/wiki/Charles_Wilson_Peale',
#   'en.wikipedia.org/wiki/Taxidermy',
#   'en.wikipedia.org/wiki/Taxidermy_art_and_science',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '7408m00': ['en.wikipedia.org/wiki/Translator'],
#  '7408p00': ['en.wikipedia.org/wiki/Performance_appraisal',
#   'en.wikipedia.org/wiki/Real_estate_appraisal'],
#  '7408q00': ['en.wikipedia.org/wiki/Court_reporter'],
#  '7409a00': ['en.wikipedia.org/wiki/Piano_tuning'],
#  '7541a00': ['en.wikipedia.org/wiki/Parking',
#   'en.wikipedia.org/wiki/Multi-storey_car_park'],
#  '7541b00': ['en.wikipedia.org/wiki/Valet_parking'],
#  '7543b00': ['en.wikipedia.org/wiki/Mobility_Carsharing'],
#  '7693a00': ['simple.wikipedia.org/wiki/Locksmith',
#   'en.wikipedia.org/wiki/Locksmith'],
#  '7693c00': ['en.wikipedia.org/wiki/Lassen_College',
#   'en.wikipedia.org/wiki/Gunsmith',
#   'en.wikipedia.org/wiki/Category:Gunsmiths',
#   'en.wikipedia.org/wiki/Patrick_Sweeney_(gunsmith)',
#   'en.wikipedia.org/wiki/Alexander_Henry_(gunsmith)'],
#  '7812a00': ['en.wikipedia.org/wiki/Walt_Disney_Studios_Motion_Pictures',
#   'en.wikipedia.org/wiki/Sony_Pictures_Entertainment'],
#  '7831a00': ['en.wikipedia.org/wiki/Movie_theater'],
#  '7832a00': ['en.wikipedia.org/wiki/List_of_theaters_and_concert_halls_in_Metro_Manila'],
#  '7840a00': ['en.wikipedia.org/wiki/Drive-in_theater'],
#  '7911a00': ['en.wikipedia.org/wiki/Billiard_hall'],
#  '7912a00': ['en.wikipedia.org/wiki/Lane'],
#  '7913a00': ['en.wikipedia.org/wiki/Arcade_game',
#   'en.wikipedia.org/wiki/Amusement_arcade'],
#  '7915a00': ['en.wikipedia.org/wiki/Casino'],
#  '7921a00': ['en.wikipedia.org/wiki/Wentworth_Park',
#   'en.wikipedia.org/wiki/Rizal_Memorial_Track_and_Football_Stadium'],
#  '7921b00': ['en.wikipedia.org/wiki/Pitch_(sports_field)',
#   'en.wikipedia.org/wiki/Baseball_park'],
#  '7922a00': ['en.wikipedia.org/wiki/Motor_racing',
#   'en.wikipedia.org/wiki/Auto_racing'],
#  '7923a00': ['en.wikipedia.org/wiki/Sports_league',
#   'en.wikipedia.org/wiki/List_of_professional_sports_leagues',
#   'en.wikipedia.org/wiki/Amateur_sports'],
#  '7923b00': ['en.wikipedia.org/wiki/Sports_league',
#   'en.wikipedia.org/wiki/Amateur_sports'],
#  '7924a00': ['en.wikipedia.org/wiki/List_of_professional_sports_teams_in_the_United_States_and_Canada',
#   'en.wikipedia.org/wiki/List_of_professional_sports_leagues'],
#  '7924b00': ['en.wikipedia.org/wiki/List_of_professional_sports_teams_in_the_United_States_and_Canada',
#   'en.wikipedia.org/wiki/List_of_professional_sports_leagues',
#   'en.wikipedia.org/wiki/Professional_sports'],
#  '7925a00': ['en.wikipedia.org/wiki/Rodeo'],
#  '7926a00': ['en.wikipedia.org/wiki/Disc_jockey',
#   'en.wikipedia.org/wiki/Disk_Jockey'],
#  '7927a00': ['en.wikipedia.org/wiki/Concert',
#   'en.wikipedia.org/wiki/Entertainment'],
#  '7928a00': ['en.wikipedia.org/wiki/Trade_fair'],
#  '7933a00': ['en.wikipedia.org/wiki/List_of_curling_clubs_in_the_United_States'],
#  '7934a00': ['en.wikipedia.org/wiki/Shooting_range'],
#  '7937a00': ['en.wikipedia.org/wiki/Health_club'],
#  '7938z00': ['en.wikipedia.org/wiki/List_of_Long_Island_recreational_facilities'],
#  '7980a00': ['simple.wikipedia.org/wiki/List_of_zoos',
#   'en.wikipedia.org/wiki/World_Association_of_Zoos_and_Aquariums',
#   'en.wikipedia.org/wiki/Zoo'],
#  '7981a00': ['en.wikipedia.org/wiki/Amusement_park',
#   'en.wikipedia.org/wiki/International_Association_of_Amusement_Parks_and_Attractions',
#   'en.wikipedia.org/wiki/List_of_defunct_amusement_parks'],
#  '7982a00': ['en.wikipedia.org/wiki/National_Amusement_Devices'],
#  '7983b00': ['en.wikipedia.org/wiki/Etnies_Skatepark',
#   'en.wikipedia.org/wiki/Rampworx_skatepark',
#   'en.wikipedia.org/wiki/Stockwell_Skatepark',
#   'en.wikipedia.org/wiki/Skatepark',
#   'en.wikipedia.org/wiki/Turf_Skatepark'],
#  '7984a00': ['en.wikipedia.org/wiki/Municipal_government_in_Canada',
#   'en.wikipedia.org/wiki/Municipal_hall'],
#  '7985a00': ['en.wikipedia.org/wiki/Dance_hall',
#   'en.wikipedia.org/wiki/Dancehall'],
#  '7986a00': ['en.wikipedia.org/wiki/Fireworks'],
#  '7989a00': ['en.wikipedia.org/wiki/Traveling_carnival'],
#  '7993a00': ['en.wikipedia.org/wiki/Nude_bathing'],
#  '7994a00': ['en.wikipedia.org/wiki/Waterpark'],
#  '7995a00': ['en.wikipedia.org/wiki/Sauna',
#   'en.wikipedia.org/wiki/Gay_bathhouse'],
#  '7997a00': ['en.wikipedia.org/wiki/List_of_gondola_lifts'],
#  '7998a00': ['en.wikipedia.org/wiki/Help:Contents',
#   'en.wikipedia.org/wiki/Snowcat_skiing',
#   'en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Special:Random',
#   'en.wikipedia.org/wiki/Ski_lift',
#   'en.wikipedia.org/wiki/Ski_tow',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '7999c00': ['en.wikipedia.org/wiki/Airborne_forces',
#   'en.wikipedia.org/wiki/Skydiving_regulation_in_the_United_States'],
#  '7999z00': ['en.wikipedia.org/wiki/Parks_and_Recreation'],
#  '8010a00': ['en.wikipedia.org/wiki/Obstetrics_and_gynaecology'],
#  '8012a00': ['en.wikipedia.org/wiki/Outpatient_surgery'],
#  '8012b00': ['en.wikipedia.org/wiki/Surgeon',
#   'en.wikipedia.org/wiki/Category:Surgical_specialties'],
#  '8013a00': ['en.wikipedia.org/wiki/World_Psychiatric_Association',
#   'en.wikipedia.org/wiki/Forensic_psychiatrist',
#   'en.wikipedia.org/wiki/Psychiatrist',
#   'en.wikipedia.org/wiki/Psychiatry',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '8014a00': ['en.wikipedia.org/wiki/Category:Ophthalmologists',
#   'en.wikipedia.org/wiki/Oculists'],
#  '8017a00': ['en.wikipedia.org/wiki/Registered_nurse'],
#  '8019a00': ['en.wikipedia.org/wiki/Anesthesiologist',
#   'en.wikipedia.org/wiki/Nurse_anesthetist'],
#  '8021a00': ['en.wikipedia.org/wiki/Chiropractic'],
#  '8023a00': ['en.wikipedia.org/wiki/Optician'],
#  '8024a00': ['en.wikipedia.org/wiki/Osteopathy'],
#  '8025a00': ['en.wikipedia.org/wiki/Podiatry'],
#  '8026a00': ['en.wikipedia.org/wiki/Doctor%27s_office'],
#  '8027a00': ['en.wikipedia.org/wiki/Audiologist'],
#  '8029a00': ['en.wikipedia.org/wiki/Licensed_Massage_Therapist'],
#  '8061a00': ['en.wikipedia.org/wiki/Hospital',
#   'en.wikipedia.org/wiki/List_of_hospitals_in_Canada'],
#  '8062a00': ['en.wikipedia.org/wiki/Midwives'],
#  '8062d00': ['en.wikipedia.org/wiki/Speech-language_pathology'],
#  '8062e00': ['en.wikipedia.org/wiki/Outpatient_surgery'],
#  '8062z00': ['en.wikipedia.org/wiki/Magnetic_resonance_imaging',
#   'en.wikipedia.org/wiki/Electronic_health_record'],
#  '8064a00': ['en.wikipedia.org/wiki/Radioactive_exposure',
#   'en.wikipedia.org/wiki/Radioactive_contamination'],
#  '8072a00': ['en.wikipedia.org/wiki/Nursing_home'],
#  '8073a00': ['en.wikipedia.org/wiki/Senior_Care'],
#  '8075a00': ['en.wikipedia.org/wiki/Piedmont_Sanatorium',
#   'en.wikipedia.org/wiki/Paimio_Sanatorium',
#   'en.wikipedia.org/wiki/Sanitarium',
#   'en.wikipedia.org/wiki/Sanitarium_%28video_game%29',
#   'en.wikipedia.org/wiki/Waverly_Hills_Sanatorium',
#   'en.wikipedia.org/wiki/Sanatorium',
#   'en.wikipedia.org/wiki/The_Sanitarium',
#   'en.wikipedia.org/wiki/Sanitarium,_California',
#   'en.wikipedia.org/wiki/Welcome_Home_%28Sanitarium%29'],
#  '8076a00': ['en.wikipedia.org/wiki/Physical_medicine_and_rehabilitation'],
#  '8076b00': ['en.wikipedia.org/wiki/Drug_rehabilitation'],
#  '8080a00': ['en.wikipedia.org/wiki/Acupuncture'],
#  '8080b10': ['en.wikipedia.org/wiki/Dietitian'],
#  '8080c00': ['en.wikipedia.org/wiki/Home_care'],
#  '8080d00': ['en.wikipedia.org/wiki/Hypnotherapy'],
#  '8080e00': ['en.wikipedia.org/wiki/Naturopathy'],
#  '8080f00': ['en.wikipedia.org/wiki/Psychology',
#   'en.wikipedia.org/wiki/Psychologist'],
#  '8080g00': ['en.wikipedia.org/wiki/Respiratory_driven_protocols',
#   'en.wikipedia.org/wiki/Respiratory_therapist',
#   'en.wikipedia.org/wiki/German_Respiratory_Society',
#   'en.wikipedia.org/wiki/Certified_Case_Manager',
#   'en.wikipedia.org/wiki/Respiratory_therapy'],
#  '8080h00': ['en.wikipedia.org/wiki/Social_services'],
#  '8081a00': ['en.wikipedia.org/wiki/Medical_laboratory'],
#  '8082a00': ['en.wikipedia.org/wiki/Genetic_engineering',
#   'en.wikipedia.org/wiki/List_of_genetics_research_organizations'],
#  '8083a00': ['en.wikipedia.org/wiki/Dental_laboratory',
#   'en.wikipedia.org/wiki/Denturist'],
#  '8084a00': ['en.wikipedia.org/wiki/Blood_bank'],
#  '8084c00': ['en.wikipedia.org/wiki/Donation_of_plasma'],
#  '8085z00': ['en.wikipedia.org/wiki/Counselling_psychology'],
#  '8111a00': ['en.wikipedia.org/wiki/Alternative_dispute_resolution'],
#  '8111b00': ['en.wikipedia.org/wiki/Solicitor',
#   'en.wikipedia.org/wiki/Barrister'],
#  '8111c00': ['en.wikipedia.org/wiki/Paralegal_studies',
#   'en.wikipedia.org/wiki/Portal:Contents',
#   'en.wikipedia.org/wiki/Special:Random',
#   'en.wikipedia.org/wiki/Agricultural_law',
#   'en.wikipedia.org/wiki/Paralegal',
#   'en.wikipedia.org/wiki/Portal:Current_events'],
#  '8292a20': ['en.wikipedia.org/wiki/Art_museum',
#   'en.wikipedia.org/wiki/Museum',
#   'en.wikipedia.org/wiki/List_of_art_museums'],
#  '8292b00': ['en.wikipedia.org/wiki/Planetarium',
#   'en.wikipedia.org/wiki/List_of_planetariums'],
#  '8293a00': ['en.wikipedia.org/wiki/Zoology'],
#  '8303a00': ['en.wikipedia.org/wiki/Secondary_school',
#   'en.wikipedia.org/wiki/Gyan_Devi_Public_School_Sr._Secondary',
#   'en.wikipedia.org/wiki/Public_high_school',
#   'en.wikipedia.org/wiki/Public_school_(UK)'],
#  '8304b00': ['en.wikipedia.org/wiki/Private_Boarding_School'],
#  '8322a00': ['en.wikipedia.org/wiki/Dance_music'],
#  '8323z00': ['en.wikipedia.org/wiki/List_of_colleges_and_universities_in_New_York_City'],
#  '8324a00': ['en.wikipedia.org/wiki/Vocational_school'],
#  '8620a00': ['en.wikipedia.org/wiki/Wikipedia:Community_Portal',
#   'en.wikipedia.org/wiki/Trade_association',
#   'en.wikipedia.org/wiki/Portal:Contents',
#   'en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Professional_association',
#   'en.wikipedia.org/wiki/Category:Professional_associations'],
#  '8630a00': ['en.wikipedia.org/wiki/History_of_Trade_Unionism',
#   'en.wikipedia.org/wiki/Trade_unions_in_Colombia',
#   'en.wikipedia.org/wiki/Conservative_Trade_Unionists',
#   'en.wikipedia.org/wiki/Trade_union'],
#  '8641a00': ['en.wikipedia.org/wiki/Girl_Guides',
#   'en.wikipedia.org/wiki/Non-aligned_Scouting_and_Scout-like_organisations'],
#  '8642a00': ['en.wikipedia.org/wiki/YMHA'],
#  '8644a00': ['en.wikipedia.org/wiki/Special_interests'],
#  '8650a00': ['en.wikipedia.org/wiki/List_of_general_fraternities',
#   'en.wikipedia.org/wiki/Fraternal_benefit_society'],
#  '8660a00': ['en.wikipedia.org/wiki/Category:Fraternal_service_organizations',
#   'en.wikipedia.org/wiki/List_of_general_fraternities'],
#  '8671a00': ['en.wikipedia.org/wiki/Conversion_of_non-Muslim_places_of_worship_into_mosques'],
#  '8672a00': ['en.wikipedia.org/wiki/Dissolution_of_the_Monasteries',
#   'en.wikipedia.org/wiki/Monasteries'],
#  '8673a00': ['en.wikipedia.org/wiki/Charitable_organization',
#   'en.wikipedia.org/wiki/Fundraising'],
#  '8910a00': ['en.wikipedia.org/wiki/Wikipedia:Community_Portal',
#   'en.wikipedia.org/wiki/Outline_of_sustainability',
#   'en.wikipedia.org/wiki/Wikipedia:Contact_us',
#   'en.wikipedia.org/wiki/Environmental_consulting',
#   'en.wikipedia.org/wiki/Environmentalist'],
#  '8910z00': ['en.wikipedia.org/wiki/Medical_laboratory'],
#  '8912a00': ['en.wikipedia.org/wiki/Surveying'],
#  '8912b00': ['en.wikipedia.org/wiki/Quantity_surveyor'],
#  '8912x00': ['en.wikipedia.org/wiki/Wireline_%28cabling%29'],
#  '8912x10': ['en.wikipedia.org/wiki/Landman_%28oil_worker%29'],
#  '8913b00': ['en.wikipedia.org/wiki/Elevator_inspector'],
#  '8914a00': ['en.wikipedia.org/wiki/Geotechnical_investigation'],
#  '8915a00': ['en.wikipedia.org/wiki/Architects_%28British_band%29',
#   'en.wikipedia.org/wiki/Architect'],
#  '8916a00': ['en.wikipedia.org/wiki/Bioreactor'],
#  '8918b00': ['en.wikipedia.org/wiki/Internet_service_provider'],
#  '8941a00': ['en.wikipedia.org/wiki/Category:Municipal_police_departments_of_the_United_States',
#   'en.wikipedia.org/wiki/Municipal_police',
#   'en.wikipedia.org/wiki/San_Juan_Municipal_Police'],
#  '8942a00': ['en.wikipedia.org/wiki/Volunteer_fire_department',
#   'en.wikipedia.org/wiki/Firefighting_worldwide',
#   'en.wikipedia.org/wiki/Firefighting_in_the_United_States'],
#  '8943a00': ['en.wikipedia.org/wiki/Fire_department'],
#  '8944a00': ['en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_the_United_States',
#   'en.wikipedia.org/wiki/Botanic_gardens'],
#  '8947a00': ['en.wikipedia.org/wiki/Consulate',
#   'en.wikipedia.org/wiki/Diplomatic_mission'],
#  '8947z00': ['en.wikipedia.org/wiki/Official',
#   'en.wikipedia.org/wiki/Clerk_(municipal_official)'],
#  '8950a00': ['en.wikipedia.org/wiki/Maplehurst_Correctional_Complex',
#   'en.wikipedia.org/wiki/List_of_correctional_facilities_in_Ontario',
#   'en.wikipedia.org/wiki/Prison']}

# %% [markdown]
# # Fetch Wikipedia Text

# %%
query = "Goat-sheep_chimerae"
req = urlopen("https://en.wikipedia.org/w/api.php?format=json&origin=*&action=query&prop=extracts&exlimit=max&redirects=true&titles="+query)

# %%
response = json.loads(req.read().decode("utf-8"))
response['query']['pages']
# Out:
# {'734858': {'extract': '<p>A <b>sheep–goat chimera</b> (sometimes called a <b>geep</b> in popular media) is a chimera produced by combining the embryos of a goat and a sheep; the resulting animal has cells of both sheep and goat origin. A sheep-goat chimera should not be confused with a sheep-goat hybrid, which can result when a goat mates with a sheep.</p>\n<h2><span id="History">History</span></h2>\n<p>The first sheep-goat chimeras were created by researchers at the Institute of Animal Physiology in Cambridge, England by combining sheep embryos with goat embryos. They reported their results in 1984. The successful chimeras were a mosaic of goat and sheep tissue. The parts that grew from the sheep embryo were woolly. Those that grew from the goat embryo were hairy.</p>\n<h2><span id="Characteristics">Characteristics</span></h2>\n<p>In a chimera, each set of cells (germ line) keeps its own species\' identity instead of being intermediate in type between the parental species. Because the chimera contains cells from two different genetic individuals, and each of these arose by normal mating, it has <i>four</i> parents. In contrast, a hybrid has only two parents.</p>\n<p>A sheep-goat chimera may be fertile, but it passes on either sheep or goat genes, depending on whether its reproductive organs were formed from the goat embryo or from the sheep embryo (i.e., whichever germ-line formed the ovaries or testes).</p>\n<p>The term <i>shoat</i> is sometimes used for sheep-goat hybrids and chimeras, but that term more conventionally means a young piglet.</p>\n<p>The most convenient way of identifying a geep is to simply look at the animal\'s tail. A geep\'s tail extends horizontally from the base of the spine combining the characteristics of a sheep\'s and goat\'s tail.</p>\n<h2><span id="References">References</span></h2>',
#   'ns': 0,
#   'pageid': 734858,
#   'title': 'Sheep–goat chimera'}}

# %%
for idx in iter(response['query']['pages']):
    text = response['query']['pages'][idx]['extract']

# %%
import html2text

# %%
cleaner = re.compile('<.*?>')
cleantext = re.sub(cleaner, '', text)
print(cleantext)
# Out:
# A sheep–goat chimera (sometimes called a geep in popular media) is a chimera produced by combining the embryos of a goat and a sheep; the resulting animal has cells of both sheep and goat origin. A sheep-goat chimera should not be confused with a sheep-goat hybrid, which can result when a goat mates with a sheep.
# History
# The first sheep-goat chimeras were created by researchers at the Institute of Animal Physiology in Cambridge, England by combining sheep embryos with goat embryos. They reported their results in 1984. The successful chimeras were a mosaic of goat and sheep tissue. The parts that grew from the sheep embryo were woolly. Those that grew from the goat embryo were hairy.
# Characteristics
# In a chimera, each set of cells (germ line) keeps its own species' identity instead of being intermediate in type between the parental species. Because the chimera contains cells from two different genetic individuals, and each of these arose by normal mating, it has four parents. In contrast, a hybrid has only two parents.
# A sheep-goat chimera may be fertile, but it passes on either sheep or goat genes, depending on whether its reproductive organs were formed from the goat embryo or from the sheep embryo (i.e., whichever germ-line formed the ovaries or testes).
# The term shoat is sometimes used for sheep-goat hybrids and chimeras, but that term more conventionally means a young piglet.
# The most convenient way of identifying a geep is to simply look at the animal's tail. A geep's tail extends horizontally from the base of the spine combining the characteristics of a sheep's and goat's tail.
# References

# %%
h = html2text.HTML2Text()
h.ignore_emphasis = True
h.ignore_images = True
h.ignore_links = True
h.ignore_tables = True
a = h.handle(text)
print(text)
# Out:
# <p>A <b>sheep–goat chimera</b> (sometimes called a <b>geep</b> in popular media) is a chimera produced by combining the embryos of a goat and a sheep; the resulting animal has cells of both sheep and goat origin. A sheep-goat chimera should not be confused with a sheep-goat hybrid, which can result when a goat mates with a sheep.</p>
# <h2><span id="History">History</span></h2>
# <p>The first sheep-goat chimeras were created by researchers at the Institute of Animal Physiology in Cambridge, England by combining sheep embryos with goat embryos. They reported their results in 1984. The successful chimeras were a mosaic of goat and sheep tissue. The parts that grew from the sheep embryo were woolly. Those that grew from the goat embryo were hairy.</p>
# <h2><span id="Characteristics">Characteristics</span></h2>
# <p>In a chimera, each set of cells (germ line) keeps its own species' identity instead of being intermediate in type between the parental species. Because the chimera contains cells from two different genetic individuals, and each of these arose by normal mating, it has <i>four</i> parents. In contrast, a hybrid has only two parents.</p>
# <p>A sheep-goat chimera may be fertile, but it passes on either sheep or goat genes, depending on whether its reproductive organs were formed from the goat embryo or from the sheep embryo (i.e., whichever germ-line formed the ovaries or testes).</p>
# <p>The term <i>shoat</i> is sometimes used for sheep-goat hybrids and chimeras, but that term more conventionally means a young piglet.</p>
# <p>The most convenient way of identifying a geep is to simply look at the animal's tail. A geep's tail extends horizontally from the base of the spine combining the characteristics of a sheep's and goat's tail.</p>
# <h2><span id="References">References</span></h2>

# %%
a.replace("\n", "")
# Out:
# "A sheep–goat chimera (sometimes called a geep in popular media) is a chimeraproduced by combining the embryos of a goat and a sheep; the resulting animalhas cells of both sheep and goat origin. A sheep-goat chimera should not beconfused with a sheep-goat hybrid, which can result when a goat mates with asheep.## HistoryThe first sheep-goat chimeras were created by researchers at the Institute ofAnimal Physiology in Cambridge, England by combining sheep embryos with goatembryos. They reported their results in 1984. The successful chimeras were amosaic of goat and sheep tissue. The parts that grew from the sheep embryowere woolly. Those that grew from the goat embryo were hairy.## CharacteristicsIn a chimera, each set of cells (germ line) keeps its own species' identityinstead of being intermediate in type between the parental species. Becausethe chimera contains cells from two different genetic individuals, and each ofthese arose by normal mating, it has four parents. In contrast, a hybrid hasonly two parents.A sheep-goat chimera may be fertile, but it passes on either sheep or goatgenes, depending on whether its reproductive organs were formed from the goatembryo or from the sheep embryo (i.e., whichever germ-line formed the ovariesor testes).The term shoat is sometimes used for sheep-goat hybrids and chimeras, but thatterm more conventionally means a young piglet.The most convenient way of identifying a geep is to simply look at theanimal's tail. A geep's tail extends horizontally from the base of the spinecombining the characteristics of a sheep's and goat's tail.## References"

# %%
import os

root = os.path.join(os.path.expanduser('~'), 'part', 'corpus')
if not os.path.exists(root):
    os.makedirs(root)

# %%
import random
random.seed(123)

# %%
def get_wikipedia_text(response):
    text = []
    for idx in iter(response['query']['pages']):
        if 'extract' in response['query']['pages'][idx]:
            text.append(response['query']['pages'][idx]['extract'])
    
    return text

# %%
def urlEncodeNonAscii(b):
    return re.sub('[\x80-\xFF]', lambda c: '%%%02x' % ord(c.group(0)), b)

def iriToUri(iri):
    parts= urlparse(iri)
    return urlunparse(
        part.encode('idna') if parti==1 else urlEncodeNonAscii(part.encode('utf-8'))
        for parti, part in enumerate(parts)
    )

# %%
cleaner = re.compile('<.*?>')
blacklist = ['Help:', 'Wikipedia:', 'Special:', 'Portal:']
for code, urls in code_url_map.items():
    code_path = os.path.join(root, code)
    os.makedirs(code_path, exist_ok=True)
    
    with open(os.path.join(code_path, 'linkmap.tsv'), 'w') as linkmap:
        for url in urls:
            query = quote_plus(url.split('/')[-1])
            req = urlopen("https://en.wikipedia.org/w/api.php?format=json&origin=*&action=query&prop=extracts&exlimit=max&redirects=true&titles="+query)
            response = json.loads(req.read().decode("utf-8"))
            text = get_wikipedia_text(response)
            
            if not text:
                continue
              
            cleantext = re.sub(cleaner, '', text[0])
            
            file_name = query + "-" + str(random.randint(0,30000))
            linkmap.write(url + '\t' + str(file_name) + '.txt\n')
            
            with open(os.path.join(code_path, str(file_name) + '.html'), 'w') as o:
                o.write(text[0])
            with open(os.path.join(code_path, str(file_name) + '.txt'), 'w') as o:
                o.write(cleantext)

# %%
path = os.path.join(os.path.expanduser('~'), 'part', 'corpus')
os.listdir(path)
# Out:
# ['7925a00',
#  '8083a00',
#  '1525b00',
#  '7294a00',
#  '8943a00',
#  '3982a00',
#  '7391a00',
#  '0190z10',
#  '7408h00',
#  '2001a00',
#  '7982a00',
#  '7937a00',
#  '7408p00',
#  '5991b00',
#  '0190d00',
#  '6650a10',
#  '5998a00',
#  '8673a00',
#  '1713b00',
#  '5421a00',
#  '3590f00',
#  '7054a00',
#  '7693a00',
#  '8111b00',
#  '1403a00',
#  '5814a00',
#  '1731x00',
#  '4951a00',
#  '8080g00',
#  '6412a00',
#  '7312c00',
#  '7541a00',
#  '7928a00',
#  '0735a00',
#  '1764a00',
#  '8650a00',
#  '4891a00',
#  '5122a00',
#  '5993b00',
#  '3496a00',
#  '1511a00',
#  '0140a00',
#  '5055a00',
#  '2331a00',
#  '5259a00',
#  '0121d00',
#  '1394a60',
#  '8026a00',
#  '5212a00',
#  '5045a00',
#  '1534a00',
#  '7041b00',
#  '7923b00',
#  '8062z00',
#  '3073c00',
#  '6390a00',
#  '1770a00',
#  '8085z00',
#  '7408b10',
#  '3983a00',
#  '8947a00',
#  '1101a00',
#  '8944a00',
#  '6580a00',
#  '4812a00',
#  '3821a00',
#  '1812a00',
#  '2990a00',
#  '2003a00',
#  '8014a00',
#  '3590b00',
#  '7408c20',
#  '4113a00',
#  '7999c00',
#  '1715b00',
#  '1394h10',
#  '1771a00',
#  '1397b10',
#  '1395c10',
#  '6150a00',
#  '1624a00',
#  '1631x00',
#  '1524a00',
#  '5221b00',
#  '5422a00',
#  '4910a00',
#  '5813b00',
#  '0150z00',
#  '1635a00',
#  '8075a00',
#  '8324a00',
#  '6650a00',
#  '2811b00',
#  '5522a00',
#  '6414a00',
#  '3590e00',
#  '5996h00',
#  '8064a00',
#  '8080f00',
#  '5990a00',
#  '8080a00',
#  '7989a00',
#  '2981b00',
#  '0190c00',
#  '6250a00',
#  '1623a00',
#  '0742a00',
#  '8942a00',
#  '7408g00',
#  '3798a00',
#  '5240a00',
#  '1394a40',
#  '1622a00',
#  '7394a00',
#  '5172b00',
#  '3065a00',
#  '8292a20',
#  '7407b00',
#  '2052c00',
#  '0122a00',
#  '0121b00',
#  '5044a00',
#  '0190z00',
#  '4957a00',
#  '8072a00',
#  '2310b00',
#  '5053a00',
#  '1634a00',
#  '1394a50',
#  '7320a00',
#  '3590j00',
#  '7403c00',
#  '8292b00',
#  '2060a00',
#  '1752a00',
#  '6140a00',
#  '3871a00',
#  '7832a00',
#  '5322a00',
#  '7915a00',
#  '8082a00',
#  '7995a00',
#  '0190b00',
#  '7926a00',
#  '8642a00',
#  '7924a00',
#  '5196b00',
#  '5321a00',
#  '8013a00',
#  '8947z00',
#  '1526a00',
#  '3062a00',
#  '2052a00',
#  '8084a00',
#  '5154a00',
#  '7693c00',
#  '1394a30',
#  '5342a00',
#  '5172a00',
#  '8080c00',
#  '4120c00',
#  '4580a00',
#  '8084c00',
#  '5940a00',
#  '5996b00',
#  '2620a00',
#  '2042a00',
#  '4251b00',
#  '1754a00',
#  '5532a00',
#  '7980a00',
#  '0730b00',
#  '7927a00',
#  '7985a00',
#  '5984a00',
#  '7812a00',
#  '0791a00',
#  '1830d00',
#  '4956a00',
#  '7923a00',
#  '2352d00',
#  '5252a00',
#  '3282a00',
#  '5433a00',
#  '2850a00',
#  '7052a00',
#  '2001c00',
#  '7986a00',
#  '5524b00',
#  '1528a00',
#  '7981a00',
#  '3066a00',
#  '7393a00',
#  '8913b00',
#  '7408c40',
#  '8910z00',
#  '5812a20',
#  '2494a00',
#  '4952a00',
#  '7921a00',
#  '0982a00',
#  '3799a00',
#  '3291b00',
#  '1513a00',
#  '0130a00',
#  '0730z00',
#  '5714a00',
#  '3294a00',
#  '1770b00',
#  '2633a00',
#  '2420b00',
#  '2081a00',
#  '5080a00',
#  '8644a00',
#  '5524a00',
#  '3590d00',
#  '4959a00',
#  '3282c00',
#  '1102a00',
#  '5180a00',
#  '6411b00',
#  '1783x20',
#  '3694a00',
#  '5060a00',
#  '6120a00',
#  '7051a00',
#  '7913a00',
#  '8941a00',
#  '1394c00',
#  '1001a00',
#  '8061a00',
#  '2011c00',
#  '4892a00',
#  '0630a00',
#  '7831a00',
#  '0121a00',
#  '1745a00',
#  '5341a00',
#  '2815b00',
#  '4117d60',
#  '8019a00',
#  '7997a00',
#  '8080e00',
#  '5511a00',
#  '8915a00',
#  '6240a00',
#  '3590i00',
#  '0190a00',
#  '2044b00',
#  '1783a20',
#  '7061a00',
#  '4263a00',
#  '8021a00',
#  '1783a10',
#  '4112a00',
#  '2043a00',
#  '5812b00',
#  '5064a00',
#  '7408a10',
#  '6632a00',
#  '2420a00',
#  '7312b00',
#  '1780a00',
#  '8027a00',
#  '1633a00',
#  '5823b00',
#  '2081b00',
#  '6531a00',
#  '8910a00',
#  '2082b00',
#  '2873a00',
#  '4118a00',
#  '3590x00',
#  '1523a00',
#  '6541a00',
#  '5314z00',
#  '3360b00',
#  '3282b00',
#  '3072a00',
#  '8012a00',
#  '6670b00',
#  '7063a00',
#  '4117a00',
#  '8081a00',
#  '5091a00',
#  '7312a00',
#  '8076a00',
#  '8012b00',
#  '4955a00',
#  '3826z00',
#  '1391a00',
#  '1776a00',
#  '4950a00',
#  '2081c00',
#  '7408m00',
#  '7543b00',
#  '5231a00',
#  '4231a00',
#  '7924b00',
#  '5715a00',
#  '7408l00',
#  '7912a00',
#  '2750d00',
#  '3360d00',
#  '3970a00',
#  '3691a00',
#  '8010a00',
#  '2001d00',
#  '7408c10',
#  '2811a00',
#  '5101a00',
#  '7994a00',
#  '8062a00',
#  '5991a00',
#  '3591a00',
#  '3320a00',
#  '8323z00',
#  '2030a00',
#  '8073a00',
#  '5191a00',
#  '2850c00',
#  '0730a00',
#  '4111a00',
#  '5811c00',
#  '7262a00',
#  '2052z00',
#  '8293a00',
#  '8916a00',
#  '5161a00',
#  '1783b00',
#  '8080h00',
#  '2820z00',
#  '1394g00',
#  '3597a00',
#  '7291a00',
#  '8029a00',
#  '7220b00',
#  '7998a00',
#  '4950b00',
#  '2750a00',
#  '1396a00',
#  '7999z00',
#  '3492a00',
#  '7934a00',
#  '2491a00',
#  '1393a10',
#  '7408i00',
#  '8912x10',
#  '8062d00',
#  '6532a00',
#  '8672a00',
#  '5996c00',
#  '7401a00',
#  '7408e00',
#  '6022a00',
#  '2632b00',
#  '5291a00',
#  '4117b00',
#  '7993a00',
#  '1393c00',
#  '7541b00',
#  '2815a00',
#  '2003c00',
#  '2850b00',
#  '4820a00',
#  '2833a00',
#  '6230a00',
#  '2002a00',
#  '8950a00',
#  '2011a00',
#  '0731a20',
#  '3592a00',
#  '4220a00',
#  '4479a00',
#  '7983b00',
#  '7922a00',
#  '2051a00',
#  '5041a00',
#  '8912x00',
#  '8080d00',
#  '7933a00',
#  '5032a00',
#  '2291a00',
#  '5811a20',
#  '8914a00',
#  '4811a00',
#  '5920a00',
#  '6501a00',
#  '5114a00',
#  '1757a00',
#  '1625a00',
#  '3797a00',
#  '8304b00',
#  '5811b00',
#  '7297a00',
#  '8017a00',
#  '8912b00',
#  '1002a00',
#  '1638a00',
#  '1772a00',
#  '7408a20',
#  '2812b00',
#  '7298a00',
#  '7407a00',
#  '8076b00',
#  '2041b00',
#  '7408q00',
#  '7292a00',
#  '6542a00',
#  '4000a00',
#  '7408d10',
#  '7403b00',
#  '2051b00',
#  '0170a00',
#  '2003b00',
#  '4462a00',
#  '8912a00',
#  '7292b00',
#  '8660a00',
#  '8111c00',
#  '3064a00',
#  '2750b00',
#  '1716a00',
#  '5042a00',
#  '8620a00',
#  '7911a00',
#  '7031b00',
#  '7409a00',
#  '1732a00',
#  '0200a00',
#  '3495a00',
#  '3570b00',
#  '7984a00',
#  '6230b10',
#  '1636a00',
#  '2082a00',
#  '7210a00',
#  '8062e00',
#  '8024a00',
#  '6660a10',
#  '8671a00',
#  '0160a00',
#  '6210a00',
#  '5813c00',
#  '0123a00',
#  '8630a00',
#  '1394h00',
#  '5912a00',
#  '4118b00',
#  '4281a00',
#  '5108a00',
#  '6670c00',
#  '6023a00',
#  '3073a00',
#  '8111a00',
#  '5061a00',
#  '3790z00',
#  '5711a00',
#  '2090a00',
#  '6411a00',
#  '8918b00',
#  '0190f30',
#  '3072b00',
#  '4950z00',
#  '0150a20',
#  '2813a00',
#  '8080b10',
#  '5995a00',
#  '4115a00',
#  '5302a00',
#  '2872a00',
#  '4871a00',
#  '2710b00',
#  '6670a00',
#  '7031a00',
#  '8025a00',
#  '7408k00',
#  '5112a00',
#  '6550a00',
#  '7840a00',
#  '0981a00',
#  '3320b00',
#  '6520a00',
#  '7938z00',
#  '8023a00',
#  '3292a00',
#  '1782f00',
#  '3493a00',
#  '3297a00',
#  '5433d00',
#  '2001b00',
#  '1741x00',
#  '5140a00',
#  '3073b00',
#  '8303a00',
#  '7313b00',
#  '7221a00',
#  '4210a00',
#  '8641a00',
#  '2002b00',
#  '5823a00',
#  '6412b00',
#  '5093a00',
#  '3491a00',
#  '7408f00',
#  '1394a00',
#  '7041a00',
#  '0210a00',
#  '8322a00',
#  '7921b00',
#  '1395b30',
#  '5063a00',
#  '5301a00',
#  '3296a00',
#  '1396b00']
